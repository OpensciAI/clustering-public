# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from sensorfabric.athena import athena
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import utils

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pyathena
# Out:
# Requirement already satisfied: pyathena in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (3.0.5)
# Requirement already satisfied: boto3>=1.26.4 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from pyathena) (1.28.2)
# Requirement already satisfied: botocore>=1.29.4 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from pyathena) (1.31.2)
# Requirement already satisfied: fsspec in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from pyathena) (2023.6.0)
# Requirement already satisfied: tenacity>=4.1.0 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from pyathena) (8.2.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from boto3>=1.26.4->pyathena) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from boto3>=1.26.4->pyathena) (0.6.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from botocore>=1.29.4->pyathena) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from botocore>=1.29.4->pyathena) (1.26.15)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/anaconda3/envs/menolife/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.29.4->pyathena) (1.16.0)

# %%
import sys
# !{sys.executable} -m pip install -U kaleido
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 15.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
# %set_env AWS_PROFILE=opensci
# Out:
# env: AWS_PROFILE=opensci

# %%
db = athena(database='menolife', workgroup='amyris', offlineCache=True)

# %% [markdown]
# # Pulled in query below to test # Users w at least a day of data and meeting premenopausal criteria. This says 20,567. No Way That's Right

# %%
premenopausalusers_query = """
SELECT DISTINCT o.healthid
FROM onboardingpp o
INNER JOIN symptoms s ON o.healthid = s.uid
INNER JOIN (
    SELECT uid
    FROM symptoms_sum
    WHERE days_symptoms_recorded > 0
) ss ON o.healthid = ss.uid
WHERE (o.questions = 'Let''s customize your personal health tracker!'
        OR o.questions = 'Choose the symptoms you deal with the most.'
        OR o.questions = 'How would you describe your periods?'
        OR o.questions = 'Are you on birth control?'
        OR o.questions = 'How did you enter menopause?')
    AND LENGTH(o.answers) > 0
    AND (o.answers NOT LIKE '%Hot Flashes/Night Sweats%'
        AND o.answers NOT LIKE '%I don''t have a period anymore%'
        AND o.answers NOT LIKE '%IUD%'
        AND o.answers NOT LIKE '%Pill%'
        AND o.answers NOT LIKE '%Implant%'
        AND o.answers NOT LIKE '%Shot%'
        AND o.answers NOT LIKE '%Vaginal Ring%'
        AND o.answers NOT LIKE '%Patch%'
        AND o.answers NOT LIKE '%Naturally%'
        AND o.answers NOT LIKE '%Medically%'
        AND o.answers NOT LIKE '%Hysterectomy%'
        AND o.answers NOT LIKE '%Chemotherapy%'
        OR o.answers = 'Unpredictable'
        OR o.answers = 'Regular cycle'
        OR o.answers = 'none'
    );
"""

symptoms_query = """
SELECT s.uid, s.name, COUNT(s.name) AS count
FROM symptoms s
INNER JOIN (
    SELECT uid
    FROM symptoms_sum
    WHERE days_symptoms_recorded > 0
) ss ON s.uid = ss.uid
INNER JOIN onboardingpp o ON s.uid = o.healthid
GROUP BY s.uid, s.name
ORDER BY s.uid, COUNT(s.name) DESC;
"""

premenopausalusers = db.execQuery(premenopausalusers_query, cached=True)
symptoms_data = db.execQuery(symptoms_query, cached=True)

print(premenopausalusers.shape)
# Out:
# (20567, 1)

# %%
premenopausalusers.head()

symptoms_data.shape
# Out:
# (168995, 3)

# %% [markdown]
# ### Premenopausal query. Make sure we're only keeping 1 uid per person: 1680 results seems more like it.

# %%
premenopausalusers_query = """
WITH query1 AS (
    SELECT DISTINCT healthid
    FROM onboardingpp o
    WHERE (questions = 'Let''s customize your personal health tracker!'
        OR questions = 'Choose the symptoms you deal with the most.'
        AND questions = 'How would you describe your periods?'
        AND questions = 'Are you on birth control?'
        AND questions = 'How did you enter menopause?')
        AND length(answers) > 0
        AND (
            answers NOT LIKE '%Hot Flashes/Night Sweats%'
            AND answers NOT LIKE '%I don''t have a period anymore%'
            AND answers NOT LIKE '%IUD%'
            AND answers NOT LIKE '%Pill%'
            AND answers NOT LIKE '%Implant%'
            AND answers NOT LIKE '%Shot%'
            AND answers NOT LIKE '%Vaginal Ring%'
            AND answers NOT LIKE '%Patch%'
            AND answers NOT LIKE '%Naturally%'
            AND answers NOT LIKE '%Medically%'
            AND answers NOT LIKE '%Hysterectomy%'
            AND answers NOT LIKE '%Chemotherapy%'
            OR answers = 'Unpredictable'
            OR answers = 'Regular cycle'
            OR answers = 'none'
        )
),
query2 AS (
    SELECT DISTINCT s.uid, s.name
    FROM symptoms s
    INNER JOIN (
        SELECT DISTINCT uid
        FROM symptoms_sum
        WHERE days_symptoms_recorded > 0
    ) ss ON s.uid = ss.uid
)
SELECT q1.healthid, MIN(q2.uid) AS uid, MIN(q2.name) AS name
FROM query1 q1
INNER JOIN query2 q2 ON q1.healthid = q2.uid
GROUP BY q1.healthid
ORDER BY uid;
"""

premenopausalusers = db.execQuery(premenopausalusers_query, cached=True)
print(premenopausalusers.shape)
premenopausalusers.head()
# Out:
# (1680, 3)
#                    healthid                       uid      name
# 0  5f931b94a42cd9d7053ec20f  5f931b94a42cd9d7053ec20f  spotting
# 1  5f935278a42cd9d7053ec212  5f935278a42cd9d7053ec212  bloating
# 2  5f935f5fa42cd9d7053ec21b  5f935f5fa42cd9d7053ec21b    cramps
# 3  5f937679a42cd9d7053ec227  5f937679a42cd9d7053ec227   anxiety
# 4  5f944dbfa42cd9d7053ec25d  5f944dbfa42cd9d7053ec25d  bloating

# %% [markdown]
# ### Compare to query of just UIDS from onboarding, which should be a BIGGER not a smaller number. The Query below returns 3419 users. So we need the intersection to be < 3419. Check

# %%
premenopausalusers=db.execQuery("""
SELECT distinct healthid
FROM onboardingpp o
WHERE (questions = 'Let''s customize your personal health tracker!'
    OR questions = 'Choose the symptoms you deal with the most.'
    AND   questions = 'How would you describe your periods?'
    AND questions = 'Are you on birth control?'
    AND questions = 'How did you enter menopause?')
    AND length(answers) > 0
    AND (
        (
        answers NOT LIKE '%Hot Flashes/Night Sweats%'
        and answers not like '%have a period anymore%'
        and answers not like '%IUD%'
        and answers not like '%Pill%'
        and answers not like '%Implant%'
        and answers not like '%Shot%'
        and answers not like '%Vaginal Ring%'
        and answers not like '%Patch%'
        and answers not like '%Naturally%'
        and answers not like '%Medically%'
        and answers not like '%Hysterectomy%'
        and answers not like '%Chemotherapy%'
        )
        OR answers = 'Unpredictable'
        OR answers = 'Regular cycle'
        OR answers ='none')
        order by healthid
        """,cached=True)
print(premenopausalusers.shape)
# Out:
# (3419, 1)

# %%
premenopausalusers.head()
# Out:
#                    healthid
# 0  5f931b94a42cd9d7053ec20f
# 1  5f935278a42cd9d7053ec212
# 2  5f935f5fa42cd9d7053ec21b
# 3  5f937679a42cd9d7053ec227
# 4  5f944dbfa42cd9d7053ec25d

# %%
users = db.execQuery("""
                    select s.uid, s.name, count(s.name) count from symptoms s 
                    inner join 
                    (select uid from symptoms_sum
                    where days_symptoms_recorded >= 0) ss
                    on s.uid = ss.uid
                    group by s.uid, s.name
                    order by s.uid, count(s.name) desc
                    """, cached=True)
print(users.shape)
# Out:
# (186139, 3)

# %% [markdown]
# ## Lets modify this to give me a table of symptoms for all the ids that meet these criteria

# %%
premenopausalusers_symptoms_query= """
WITH query1 AS (
    SELECT DISTINCT healthid
    FROM onboardingpp 
    WHERE (questions = 'Let''s customize your personal health tracker!'
        OR questions = 'Choose the symptoms you deal with the most.'
        AND questions = 'How would you describe your periods?'
        AND questions = 'Are you on birth control?'
        AND questions = 'How did you enter menopause?')
        AND length(answers) > 0
        AND (
            (
            answers NOT LIKE '%Hot Flashes/Night Sweats%'
            AND answers NOT LIKE '%have a period anymore%'
            AND answers NOT LIKE '%IUD%'
            AND answers NOT LIKE '%Pill%'
            AND answers NOT LIKE '%Implant%'
            AND answers NOT LIKE '%Shot%'
            AND answers NOT LIKE '%Vaginal Ring%'
            AND answers NOT LIKE '%Patch%'
            AND answers NOT LIKE '%Naturally%'
            AND answers NOT LIKE '%Medically%'
            AND answers NOT LIKE '%Hysterectomy%'
            AND answers NOT LIKE '%Chemotherapy%'
            )
            OR answers = 'Unpredictable'
            OR answers = 'Regular cycle'
            OR answers = 'none'
        )
),
query2 AS (
    SELECT s.uid, s.name, COUNT(s.name) AS count 
    FROM symptoms s
    INNER JOIN query1 q1 ON s.uid = q1.healthid
    INNER JOIN (
        SELECT uid
        FROM symptoms_sum ss
        WHERE days_symptoms_recorded > 0
        AND ss.uid IN (SELECT distinct healthid FROM query1)
    ) ss ON q1.healthid = ss.uid
    GROUP BY s.uid, s.name
)
SELECT q2.uid, q2.name, q2.count
FROM query2 q2
ORDER BY q2.uid, q2.count DESC;
"""

premenopausalusers_symptoms = db.execQuery(premenopausalusers_symptoms_query, cached=True)
print(premenopausalusers_symptoms.shape)
premenopausalusers_symptoms.head()
# Out:
# (8414, 3)
#                         uid             name  count
# 0  5f931b94a42cd9d7053ec20f         spotting      1
# 1  5f935278a42cd9d7053ec212           cramps      4
# 2  5f935278a42cd9d7053ec212  yeast_infection      3
# 3  5f935278a42cd9d7053ec212         bloating      1
# 4  5f935f5fa42cd9d7053ec21b      mood_swings      3

# %%
#Is this still keeping only the correct uids? 

# Calculate the unique number of UIDs
unique_uids_count = len(premenopausalusers_symptoms['uid'].unique())

# Display the unique number of UIDs
print("Unique number of UIDs:", unique_uids_count)
# Out:
# Unique number of UIDs: 1680

# %%
#Lets see if the df looks right

frame = pd.DataFrame()  # Empty dataframe that will contain all the dataset.
uidmap = {}
# Start breaking the users frame and extract data from it to add to the data matrix.
temp = None  # Temp dictionary that holds the symptom counts for each user.
for uid, sname, scount in zip(premenopausalusers_symptoms['uid'].values, premenopausalusers_symptoms['name'].values, premenopausalusers_symptoms['count'].values):
    if not (uid in uidmap):
        # If temp is not None (everything except for the first uid then we will concat the last uid to the frame.
        if not (temp is None):
            temp = pd.Series(temp)
            temp = temp.to_frame().T
            frame = pd.concat([frame, temp], ignore_index=True)
        temp = {}  # Start fresh again.
        temp['uid'] = uid
        uidmap[uid] = 1
    temp[sname] = scount
frame = frame.set_index(['uid']) # Set the 'uid' as the index, so it becomes easier to query.
frame = frame.fillna(0)

# %%
frame.head(5)
# Out:
#                          spotting cramps yeast_infection bloating mood_swings  \
# uid
# 5f931b94a42cd9d7053ec20f        1      0               0        0           0
# 5f935278a42cd9d7053ec212        0      4               3        1           0
# 5f935f5fa42cd9d7053ec21b        0      1               0        0           3
# 5f937679a42cd9d7053ec227        0      0               0        1           0
# 5f944dbfa42cd9d7053ec25d        0      0               0        3           0
#
#                          joint_pain fatigue anxiety irregular_beat headaches  \
# uid
# 5f931b94a42cd9d7053ec20f          0       0       0              0         0
# 5f935278a42cd9d7053ec212          0       0       0              0         0
# 5f935f5fa42cd9d7053ec21b          1       0       0              0         0
# 5f937679a42cd9d7053ec227          1       3       2              1         1
# 5f944dbfa42cd9d7053ec25d          0       0       0              0         1
#
#                           ... hair_loss itchy_skin vertigo vaginal_dryness  \
# uid                       ...
# 5f931b94a42cd9d7053ec20f  ...         0          0       0               0
# 5f935278a42cd9d7053ec212  ...         0          0       0               0
# 5f935f5fa42cd9d7053ec21b  ...         0          0       0               0
# 5f937679a42cd9d7053ec227  ...         0          0       0               0
# 5f944dbfa42cd9d7053ec25d  ...         0          0       0               0
#
#                          tingling_extremeties vomiting ovulation  \
# uid
# 5f931b94a42cd9d7053ec20f                    0        0         0
# 5f935278a42cd9d7053ec212                    0        0         0
# 5f935f5fa42cd9d7053ec21b                    0        0         0
# 5f937679a42cd9d7053ec227                    0        0         0
# 5f944dbfa42cd9d7053ec25d                    0        0         0
#
#                          painful_intercourse uti nipple_discharge
# uid
# 5f931b94a42cd9d7053ec20f                   0   0                0
# 5f935278a42cd9d7053ec212                   0   0                0
# 5f935f5fa42cd9d7053ec21b                   0   0                0
# 5f937679a42cd9d7053ec227                   0   0                0
# 5f944dbfa42cd9d7053ec25d                   0   0                0
#
# [5 rows x 45 columns]

# %%
#Note some users are still reporting hot flashes. Remove them. 

frame = frame[(frame['hot_flashes'] == 0) & (frame['night_sweats'] == 0)]

# %%
frame.head()
# Out:
#                          spotting cramps yeast_infection bloating mood_swings  \
# uid
# 5f931b94a42cd9d7053ec20f        1      0               0        0           0
# 5f935278a42cd9d7053ec212        0      4               3        1           0
# 5f935f5fa42cd9d7053ec21b        0      1               0        0           3
# 5f937679a42cd9d7053ec227        0      0               0        1           0
# 5f944dbfa42cd9d7053ec25d        0      0               0        3           0
#
#                          joint_pain fatigue anxiety irregular_beat headaches  \
# uid
# 5f931b94a42cd9d7053ec20f          0       0       0              0         0
# 5f935278a42cd9d7053ec212          0       0       0              0         0
# 5f935f5fa42cd9d7053ec21b          1       0       0              0         0
# 5f937679a42cd9d7053ec227          1       3       2              1         1
# 5f944dbfa42cd9d7053ec25d          0       0       0              0         1
#
#                           ... hair_loss itchy_skin vertigo vaginal_dryness  \
# uid                       ...
# 5f931b94a42cd9d7053ec20f  ...         0          0       0               0
# 5f935278a42cd9d7053ec212  ...         0          0       0               0
# 5f935f5fa42cd9d7053ec21b  ...         0          0       0               0
# 5f937679a42cd9d7053ec227  ...         0          0       0               0
# 5f944dbfa42cd9d7053ec25d  ...         0          0       0               0
#
#                          tingling_extremeties vomiting ovulation  \
# uid
# 5f931b94a42cd9d7053ec20f                    0        0         0
# 5f935278a42cd9d7053ec212                    0        0         0
# 5f935f5fa42cd9d7053ec21b                    0        0         0
# 5f937679a42cd9d7053ec227                    0        0         0
# 5f944dbfa42cd9d7053ec25d                    0        0         0
#
#                          painful_intercourse uti nipple_discharge
# uid
# 5f931b94a42cd9d7053ec20f                   0   0                0
# 5f935278a42cd9d7053ec212                   0   0                0
# 5f935f5fa42cd9d7053ec21b                   0   0                0
# 5f937679a42cd9d7053ec227                   0   0                0
# 5f944dbfa42cd9d7053ec25d                   0   0                0
#
# [5 rows x 45 columns]

# %%
#Now how many do I have left?

unique_uids = frame.index.unique().tolist()
unique_uids_size = len(unique_uids)
print("Size of unique_uids:", unique_uids_size)
# Out:
# Size of unique_uids: 1408

# %%
frame.to_csv('premenopausalsymptoms.csv')

# %% [markdown]
# ## Moving on to the perimenopausal UID set

# %%
## Perimenopausal Query

# %% [markdown]
# ## QUERY: How would you describe yoru periods?

# %%
query = """
select * from onboardingpp 
  where (questions = 'How would you describe your periods?')
  and length(answers) > 0
"""

results = db.execQuery(query, cached=True)

# %%
results.head(60)
# Out:
#                     healthid              community_id  \
# 0   60f3a934bea29a1eb66cefea  60f3a93227df7d3103e102bf
# 1   60bca74dbea29a1eb66c8061  60bca74bea8bf89011f263d2
# 2   60c20f71bea29a1eb66c8a89  60c20f66eb1ab928fa08191a
# 3   60d26e40bea29a1eb66cabc3  60d26e3de535908d4d4b939a
# 4   60c0afb2bea29a1eb66c8815  60c0afb1e019e61e41055177
# 5   60df75e0bea29a1eb66cc52d  60df75de27df7d3103e0d33c
# 6   60c1a154bea29a1eb66c89f6  60c1a151eb1ab928fa08189a
# 7   60c1c8abbea29a1eb66c8a0d  60c1c8a962779fa5ce932304
# 8   60b978c2bea29a1eb66c7ad8  60b978c063a11ed543ff5589
# 9   6106f9d0bea29a1eb66d1dc3  6106f9ce078c683a7ea3f6c8
# 10  5fd57d50701f5d82ee87ff63  5fd57d42163f8c355ccfc35c
# 11  60ce04b0bea29a1eb66ca241  60ce04af20d4fea19a601752
# 12  60db441bbea29a1eb66cbc90  60db4419fb42fe134dd425c2
# 13  6109491fbea29a1eb66d23c9  61094914078c683a7ea3fdba
# 14  60db864cbea29a1eb66cbd11  60db864a27df7d3103e0c7c5
# 15  60cef32bbea29a1eb66ca386  60cef328bf0ea448309f0609
# 16  60b3f817bea29a1eb66c704f  60b3f812622e53e128baa819
# 17  60b41aedbea29a1eb66c7094  60b41aeb09704a07492deb57
# 18  60d81ef8bea29a1eb66cb65f  60d81ef627df7d3103e0c003
# 19  60bfec64bea29a1eb66c86d0  60bfec5e831086163daeb946
# 20  60b94e3dbea29a1eb66c7a6a  60b94e3a5762307be8553f91
# 21  60c0d622bea29a1eb66c884c  60c0d620681c519db1e8e2a2
# 22  60c13dcebea29a1eb66c8927  60c13dcb681c519db1e8e432
# 23  60b113a8bea29a1eb66c6be6  60b113a609704a07492de0e1
# 24  60c1635dbea29a1eb66c8965  60c1635a62779fa5ce932272
# 25  60b32791bea29a1eb66c6f01  60b3278f622e53e128baa59c
# 26  60b2182bbea29a1eb66c6d36  60b2182909704a07492de3e0
# 27  61741fccbea29a1eb66e7add  61741fc80cd520232d33fe8e
# 28  61771a91bea29a1eb66e8352  61771a8f50db38d439a451f8
# 29  617697cfbea29a1eb66e81c5  617697cc0cd520232d340325
# 30  626220aebea29a1eb6714f0e  626220abf57de32eb215053f
# 31  6176b422bea29a1eb66e824a  6176b41f50db38d439a45093
# 32  617a1d91bea29a1eb66e8f2b  617a1d8fae95862b5944ad50
# 33  61789d22bea29a1eb66e8994  61789d2050db38d439a455d3
# 34  6179cc38bea29a1eb66e8d70  6179cc36ae95862b5944ac0e
# 35  617acbbcbea29a1eb66e90ab  617acbba50db38d439a45b75
# 36  617b6d0ebea29a1eb66e9408  617b6d0b50db38d439a45d6b
# 37  617b8ae2bea29a1eb66e9462  617b8ae0ae95862b5944b06d
# 38  617c0727bea29a1eb66e9553  617c0725ae95862b5944b11c
# 39  617d7f5bbea29a1eb66e999a  617d7f57ae95862b5944b442
# 40  617ca67abea29a1eb66e97e0  617ca67750db38d439a46058
# 41  617e12cbbea29a1eb66e9c0a  617e12c950db38d439a46383
# 42  617dbaebbea29a1eb66e9a6e  617dbae9ae95862b5944b540
# 43  617f61cbbea29a1eb66e9fe1  617f61c9ae95862b5944b977
# 44  617e31bcbea29a1eb66e9c4a  617e31b9ae95862b5944b685
# 45  617f5c24bea29a1eb66e9fcf  617f5c2250db38d439a46680
# 46  6182f11fbea29a1eb66eab38  6182f11c50db38d439a46f30
# 47  61832158bea29a1eb66eac68  61832154ae95862b5944c1fb
# 48  61850534bea29a1eb66eb1a9  61850531ae95862b5944c547
# 49  6186b866bea29a1eb66eb6a0  6186b864ae95862b5944c862
# 50  618e083dbea29a1eb66ecd98  618e083a50db38d439a486b1
# 51  618c10fbbea29a1eb66ec775  618c10f8ae95862b5944d4d1
# 52  618cd75fbea29a1eb66ec9cf  618cd75850db38d439a483f2
# 53  618e95dcbea29a1eb66ecedc  618e95d950db38d439a487ef
# 54  61907e30bea29a1eb66ed422  61907e2e79f9aad98f32e598
# 55  61917e81bea29a1eb66ed663  61917e7e79f9aad98f32e7ec
# 56  6191cb8fbea29a1eb66ed7fa  6191cb8c79f9aad98f32e870
# 57  6193977ebea29a1eb66edc86  6193977c3adca54ada2e2907
# 58  61934f12bea29a1eb66edc5a  61934f1079f9aad98f32ec33
# 59  61943a00bea29a1eb66ede40  619439fe79f9aad98f32ee35
#
#                                questions  \
# 0   How would you describe your periods?
# 1   How would you describe your periods?
# 2   How would you describe your periods?
# 3   How would you describe your periods?
# 4   How would you describe your periods?
# 5   How would you describe your periods?
# 6   How would you describe your periods?
# 7   How would you describe your periods?
# 8   How would you describe your periods?
# 9   How would you describe your periods?
# 10  How would you describe your periods?
# 11  How would you describe your periods?
# 12  How would you describe your periods?
# 13  How would you describe your periods?
# 14  How would you describe your periods?
# 15  How would you describe your periods?
# 16  How would you describe your periods?
# 17  How would you describe your periods?
# 18  How would you describe your periods?
# 19  How would you describe your periods?
# 20  How would you describe your periods?
# 21  How would you describe your periods?
# 22  How would you describe your periods?
# 23  How would you describe your periods?
# 24  How would you describe your periods?
# 25  How would you describe your periods?
# 26  How would you describe your periods?
# 27  How would you describe your periods?
# 28  How would you describe your periods?
# 29  How would you describe your periods?
# 30  How would you describe your periods?
# 31  How would you describe your periods?
# 32  How would you describe your periods?
# 33  How would you describe your periods?
# 34  How would you describe your periods?
# 35  How would you describe your periods?
# 36  How would you describe your periods?
# 37  How would you describe your periods?
# 38  How would you describe your periods?
# 39  How would you describe your periods?
# 40  How would you describe your periods?
# 41  How would you describe your periods?
# 42  How would you describe your periods?
# 43  How would you describe your periods?
# 44  How would you describe your periods?
# 45  How would you describe your periods?
# 46  How would you describe your periods?
# 47  How would you describe your periods?
# 48  How would you describe your periods?
# 49  How would you describe your periods?
# 50  How would you describe your periods?
# 51  How would you describe your periods?
# 52  How would you describe your periods?
# 53  How would you describe your periods?
# 54  How would you describe your periods?
# 55  How would you describe your periods?
# 56  How would you describe your periods?
# 57  How would you describe your periods?
# 58  How would you describe your periods?
# 59  How would you describe your periods?
#
#                                             answers
# 0                                     Regular cycle
# 1                   I donâ€™t have a period anymore
# 2                   I donâ€™t have a period anymore
# 3                                     Unpredictable
# 4                                     Regular cycle
# 5                                     Unpredictable
# 6                   I donâ€™t have a period anymore
# 7                   I donâ€™t have a period anymore
# 8                                     Unpredictable
# 9                                     Regular cycle
# 10                                    Unpredictable
# 11                                    Unpredictable
# 12                                    Unpredictable
# 13                                    Unpredictable
# 14  I take birth control, and donâ€™t have a period
# 15                                    Unpredictable
# 16                                    Unpredictable
# 17                                    Unpredictable
# 18                                    Unpredictable
# 19  I take birth control, and donâ€™t have a period
# 20                                    Unpredictable
# 21                                    Regular cycle
# 22                                    Unpredictable
# 23                                    Unpredictable
# 24                                    Unpredictable
# 25                  I donâ€™t have a period anymore
# 26                  I donâ€™t have a period anymore
# 27                                    Unpredictable
# 28                                    Unpredictable
# 29                                    Unpredictable
# 30                                    Unpredictable
# 31                                    Regular cycle
# 32                  I donâ€™t have a period anymore
# 33                  I donâ€™t have a period anymore
# 34                                    Unpredictable
# 35                  I donâ€™t have a period anymore
# 36                  I donâ€™t have a period anymore
# 37                                    Unpredictable
# 38                                    Unpredictable
# 39                                    Regular cycle
# 40                                    Unpredictable
# 41                                    Regular cycle
# 42                                    Unpredictable
# 43                                    Unpredictable
# 44  I take birth control, and donâ€™t have a period
# 45                                    Unpredictable
# 46                  I donâ€™t have a period anymore
# 47                                    Unpredictable
# 48                  I donâ€™t have a period anymore
# 49                                    Unpredictable
# 50                                    Regular cycle
# 51                                    Unpredictable
# 52  I take birth control, and donâ€™t have a period
# 53                                    Regular cycle
# 54                                    Unpredictable
# 55                                    Unpredictable
# 56                                    Unpredictable
# 57                                    Unpredictable
# 58                                    Unpredictable
# 59                                    Regular cycle

# %%
results.shape
# Out:
# (33512, 4)

# %%
symptoms = {}
for ans in results['answers'].values:
    sym = ans.split(',')
    for s in sym:
        temp = s.strip()
        if not (temp in symptoms):
            symptoms[temp] = 0
        symptoms[temp] = symptoms[temp]+1

# %%
symptoms
# Out:
# {'Regular cycle': 6420,
#  'I donâ€™t have a period anymore': 12017,
#  'Unpredictable': 13642,
#  'I take birth control': 1433,
#  'and donâ€™t have a period': 1433}

# %% [markdown]
# Now instead ask about symptoms

# %%
query = """
select * from onboardingpp 
  where (questions = 'Let''s customize your personal health tracker!' 
  or questions = 'Choose the symptoms you deal with the most.')
  and length(answers) > 0
"""

results = db.execQuery(query, cached=True)

# %%
results.head()
# Out:
#                    healthid              community_id  \
# 0  62a22ea6bea29a1eb6723576  62a22ea4f57de32eb215b8cb
# 1  62a258c6bea29a1eb67235f4  62a258c3f57de32eb215b96b
# 2  62a33009bea29a1eb6723904  62a33006f57de32eb215bb4d
# 3  62a628cabea29a1eb6724371  62a628c7607213a9ae6e8a75
# 4  62a69141bea29a1eb67244eb  62a6913e607213a9ae6e8bb6
#
#                                      questions  \
# 0  Choose the symptoms you deal with the most.
# 1  Choose the symptoms you deal with the most.
# 2  Choose the symptoms you deal with the most.
# 3  Choose the symptoms you deal with the most.
# 4  Choose the symptoms you deal with the most.
#
#                                              answers
# 0  Bloating,Brittle Hair/Nails,Hot Flashes/Night ...
# 1  Brittle Hair/Nails,Difficulty Concentrating,Ho...
# 2  Anxiety,Fatigue,Difficulty Concentrating,Hot F...
# 3  Bloating,Brittle Hair/Nails,Fatigue,Hot Flashe...
# 4  Anxiety,Bloating,Difficulty Concentrating,Fati...

# %%
results.shape
# Out:
# (41725, 4)

# %%
symptoms = {}
for ans in results['answers'].values:
    sym = ans.split(',')
    for s in sym:
        temp = s.strip()
        if not (temp in symptoms):
            symptoms[temp] = 0
        symptoms[temp] = symptoms[temp]+1

# %%
symptoms
# Out:
# {'Bloating': 23163,
#  'Brittle Hair/Nails': 14391,
#  'Hot Flashes/Night Sweats': 26051,
#  'Fatigue': 28056,
#  'Insomnia': 20500,
#  'Low Sex Drive': 20495,
#  'Mood Swings/Irritability': 24242,
#  'Signs of Aging Skin': 17970,
#  'Weight Gain': 29567,
#  'Difficulty Concentrating': 20850,
#  'Irregular Periods': 15175,
#  'Anxiety': 22827,
#  "I don't really have any symptoms that bother me.": 344,
#  "I don't really have any symptoms that bother me": 226}

# %%
symptoms['I don\'t really have any symptoms that bother me.'] += symptoms['I don\'t really have any symptoms that bother me']

# %%
del symptoms['I don\'t really have any symptoms that bother me']

# %%
# Create a frame from this, so we can save it as a nice little table. Might come handy in some situation.

frame = pd.DataFrame.from_dict(symptoms, orient='index', columns=['count'])
frame.sort_values(by=['count'], ascending=False)
# Out:
#                                                   count
# Weight Gain                                       29567
# Fatigue                                           28056
# Hot Flashes/Night Sweats                          26051
# Mood Swings/Irritability                          24242
# Bloating                                          23163
# Anxiety                                           22827
# Difficulty Concentrating                          20850
# Insomnia                                          20500
# Low Sex Drive                                     20495
# Signs of Aging Skin                               17970
# Irregular Periods                                 15175
# Brittle Hair/Nails                                14391
# I don't really have any symptoms that bother me.    570

# %% [markdown]
# Network Analysis

# %%
def createHotEncoding(symptoms, results):
    """
    Creates a one hot encoding for the symptoms, which can then be fed into a NA algorithm using R.
    
    symptoms : A list of all the symptoms we should include.
    results : The complete dataframe from onboarding that has the answers and userid.
    
    Returns a dataframe with the one hot encoding.
    """
    columns = symptoms

    data = pd.DataFrame(columns=columns)
    indexm = {}
    for i, v in enumerate(columns):
        indexm[v] = i

    row = np.zeros(len(columns), dtype='int64')
    row[2] = 1
    row[4] = 1
    series = pd.Series(row, index=columns)
    series = series.to_frame().T
    data = pd.concat([data, series], ignore_index=True)

    for (uid, ans) in zip(results['healthid'], results['answers']):
        sym = utils.extractSymptoms(ans)
        row = np.zeros(len(columns), dtype='int64')
        #row[-1] = uid # Fill the uid in at the end.
        for s in sym:
            s = s.strip()
            # This is not really a symptom so we don't care much about it.
            if s == "I don\'t really have any symptoms that bother me" or s == "I don\'t really have any symptoms that bother me.":
                continue
            row[indexm[s]] = 1
        series = pd.Series(row, index=columns)
        series = series.to_frame().T
        data = pd.concat([data, series], ignore_index=True)
        
    # Drop the column for "I don't really have any symptoms"
    data = data.drop(["I don't really have any symptoms that bother me."], axis=1)

    return data

# %%
data = createHotEncoding(frame.index.values, results)
